# %% [markdown]
# <a href="https://colab.research.google.com/github/Umang205/basic-image-processing-opencv/blob/main/Untitled19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt

img=cv2.imread("/content/HELL PARIDISE.jpg")
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.title("step 1: RBG Image")
plt.axis("off")
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

img=cv2.imread("/content/HELL PARIDISE.jpg")
#img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.title("step 1: RBG Image")
plt.axis("off")
plt.show()

# %% [markdown]
# checking the shape of image

# %%
print(img.shape)
# Out:
# (168, 300, 3)

# %% [markdown]
# basic slicing we want to extrat frist 4 row and colomn

# %%
print(img[0:5,0:5])
# Out:
# [[[21 17 22]
#   [21 19 19]
#   [18 21 12]
#   [18 23  8]
#   [17 23  4]]
#
#  [[21 17 22]
#   [21 19 19]
#   [18 21 12]
#   [18 23  8]
#   [18 24  5]]
#
#  [[21 18 20]
#   [21 19 18]
#   [21 22 13]
#   [20 23  8]
#   [18 24  5]]
#
#  [[22 20 20]
#   [22 21 17]
#   [21 22 12]
#   [21 24  9]
#   [18 24  5]]
#
#  [[22 20 19]
#   [22 22 16]
#   [22 23 13]
#   [21 24  9]
#   [19 25  8]]]

# %%
gray=cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)
plt.imshow(gray,cmap="gray")
plt.title("step2:gray image")
plt.axis("off")
plt.show()

# %%
print(gray[0:10,0:10])
# Out:
# [[19 20 19 20 19 19 18 18 19 22]
#  [19 20 19 20 20 19 18 18 15 25]
#  [19 19 21 20 20 20 18 18 19 12]
#  [21 21 21 21 20 20 19 20 24  5]
#  [20 21 22 21 21 21 20 20 20 19]
#  [22 22 22 22 21 21 21 21 19 23]
#  [23 23 22 22 22 21 22 22 20 17]
#  [24 24 23 22 22 22 22 22 17 22]
#  [26 26 25 24 24 23 22 23 24 29]
#  [23 23 21 21 20 19 18 19 27  9]]

# %%
sampled=cv2.resize(gray,(500,200))
plt.imshow(sampled,cmap="gray")
plt.title("Step3: sampling higher resolution")
plt.axis("OFF")
plt.show()

# %%
sampled=cv2.resize(img,(500,200))
img=cv2.cvtColor(img,cv2.COLOR_RGB2BGR)
plt.imshow(sampled)
plt.title("Step3: sampling higher resolution")
plt.axis("ON")
plt.show()
